# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are Sumarized.

# %% [markdown]
# **Objectives:**
# * List Popular Languages in Data Science
# * List commonly used Libraries in Data Science
# * List Data Science tools
# * Exampels of Arithemic Expressions in Python

# %% [markdown]
# Some of the popular languages that Data Sciencets use are:
# 1. Python
# 2. R
# 3. SQL
# 4. C++
# 5. Java

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. ggplot2
# 2. pandas
# 3. matplotlib
# 4. tensorflow
# 5. NumPY

# %% [markdown]
# Data Science Tools:
# | Open Source Tools|
# | -------|
# | Juputer|
# | R Studio|
# | Spider|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
(3*4)+5
# This is a simple arithetic expression to mutiply then add integers
# Out:
# 17

# %%
# This expression will covert 200 minutes to hours by diving by 60 

mininute= 200
hour= 60

mininute/hour
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author:
# Wander Boesjes
